# %% [markdown]
# # Binary Search
# https://www.geeksforgeeks.org/dsa/binary-search/

# %% [markdown]
# In order for binary search to be applied to a data structure, 2 conditions have to be fulfilled:
#
# 1) The data structure must be sorted
# 2) Access to any element of the data structure should take constant time

# %% [markdown]
# ### Step-By-Step Execution

# %%
# Start with an unordered list
arr = [2, 3, 4, 10, 40]
print(arr)
# Out:
# [2, 3, 4, 10, 40]
